# %% [markdown]
# ## **Academic Honesty**
# This assignment must be done individually and independently. You must implement the whole assignment by yourself. Academic dishonesty is not tolerated.

# %% [markdown]
# ## **Requirements**
# 1. When you work on this assignment, you should make a copy of this notebook in Google Colab. This can be done using the option `File > Save a copy in Drive` in Google Colab.
#
# 2. You should fill in your answer for each task inside the code block right under the task.
#
# 3. You should only insert your code into the designated code blocks, as mentioned above. Other than that, you shouldn't change anything else in the notebook, unless otherwise instructed.
#
# 4.  For each code block, you are free to use multiple lines of code.
#
# 5.   Even if you can only partially solve a task, you should include your code in the code block, which allows us to consider partial credit.
#
# 6.   However, your code should not raise errors. Any code raising errors will not get partial credit.
#
# 7.   We will test your code in Google Colab. Make sure your code runs in Google Colab.
#
# 9. For classification, you are expected to use `scikit-learn` (http://scikit-learn.org/stable/supervised_learning.html#supervised-learning). Refer to our Colab on classification for a tutorial of how to use scikit-learn to build classification models. The Colab has been on the Syllabus page and has been explained during lectures [(its link)](https://colab.research.google.com/drive/1Mw-f0UB72GMdw6C6G9legcyxIiDBWjFg). You can also refer to our Colab on Linear Model [(its link)](https://colab.research.google.com/drive/18hXzJCPuLa6bLxIA2BuCD20w8EOnuKM7?usp=sharing).
#
# 10. To submit your assignment, download your Colab into a .ipynb file. This can be done using the option `Download > Download .ipynb` in Google Colab.
#
# 11. Submit the downloaded .ipynb file into the Programming Assignment 1 entry in Canvas.

# %% [markdown]
# ## **Task1: Pandas:DataFrame**(40)

# %%
import pandas as pd
import numpy as np

# %%
# DATA URL SOURCES ###############################
eng_url     = 'https://andybek.com/pandas-eng'
state_url   = 'https://andybek.com/pandas-state'
party_url   = 'https://andybek.com/pandas-party'
liberal_url = 'https://andybek.com/pandas-liberal'
ivies_url   = 'https://andybek.com/pandas-ivies'
##################################################

# %%
#Create 5 dataframes(eng,state,party,liberal,ivies) from the 5 csv files uploaded above.
eng = pd.read_csv(eng_url)
state = pd.read_csv(state_url)
party = pd.read_csv(party_url)
liberal = pd.read_csv(liberal_url)
ivies = pd.read_csv(ivies_url)

# %%
#Use a function to retreive information on the first 10 rows of your dataframe.
eng.head(10)
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
# 5         Worcester Polytechnic Institute (WPI)  Engineering
# 6              Carnegie Mellon University (CMU)  Engineering
# 7        Rensselaer Polytechnic Institute (RPI)  Engineering
# 8               Georgia Institute of Technology  Engineering
# 9                      Colorado School of Mines  Engineering
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $72,200.00              $126,000.00
# 1            $75,500.00              $123,000.00
# 2            $71,800.00              $122,000.00
# 3            $62,400.00              $114,000.00
# 4            $62,200.00              $114,000.00
# 5            $61,000.00              $114,000.00
# 6            $61,800.00              $111,000.00
# 7            $61,100.00              $110,000.00
# 8            $58,300.00              $106,000.00
# 9            $58,100.00              $106,000.00

# %%
state.head(10)
# Out:
#                                          School Name School Type  \
# 0                 University of California, Berkeley       State
# 1                       University of Virginia (UVA)       State
# 2                           Cal Poly San Luis Obispo       State
# 3     University of California at Los Angeles (UCLA)       State
# 4         University of California, San Diego (UCSD)       State
# 5                    University of California, Davis       State
# 6             University of Colorado - Boulder (UCB)       State
# 7             University of California, Irvine (UCI)       State
# 8  University of Illinois at Urbana-Champaign (UIUC)       State
# 9                               Texas A&M University       State
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $59,900.00              $112,000.00
# 1            $52,700.00              $103,000.00
# 2            $57,200.00              $101,000.00
# 3            $52,600.00              $101,000.00
# 4            $51,100.00              $101,000.00
# 5            $52,300.00               $99,600.00
# 6            $47,100.00               $97,600.00
# 7            $48,300.00               $96,700.00
# 8            $52,900.00               $96,100.00
# 9            $49,700.00               $96,100.00

# %%
party.head(10)
# Out:
#                                          School Name School Type  \
# 0  University of Illinois at Urbana-Champaign (UIUC)       Party
# 1               University of Maryland, College Park       Party
# 2     University of California, Santa Barbara (UCSB)       Party
# 3                  University of Texas (UT) - Austin       Party
# 4      State University of New York (SUNY) at Albany       Party
# 5                         University of Florida (UF)       Party
# 6                   Louisiana State University (LSU)       Party
# 7                        University of Georgia (UGA)       Party
# 8                Pennsylvania State University (PSU)       Party
# 9                     Arizona State University (ASU)       Party
#
#   Starting Median Salary Mid-Career Median Salary
# 0            $52,900.00               $96,100.00
# 1            $52,000.00               $95,000.00
# 2            $50,500.00               $95,000.00
# 3            $49,700.00               $93,900.00
# 4            $44,500.00               $92,200.00
# 5            $47,100.00               $87,900.00
# 6            $46,900.00               $87,800.00
# 7            $44,100.00               $86,000.00
# 8            $49,900.00               $85,700.00
# 9            $47,400.00               $84,100.00

# %%
liberal.head(10)
# Out:
#                      School Name   School Type Starting Median Salary  \
# 0            Bucknell University  Liberal Arts            $54,100.00
# 1             Colgate University  Liberal Arts            $52,800.00
# 2                Amherst College  Liberal Arts            $54,500.00
# 3              Lafayette College  Liberal Arts            $53,900.00
# 4                Bowdoin College  Liberal Arts            $48,100.00
# 5      College of the Holy Cross  Liberal Arts            $50,200.00
# 6             Occidental College  Liberal Arts            $51,900.00
# 7  Washington and Lee University  Liberal Arts            $53,600.00
# 8             Swarthmore College  Liberal Arts            $49,700.00
# 9               Davidson College  Liberal Arts            $46,100.00
#
#   Mid-Career Median Salary
# 0             $110,000.00
# 1             $108,000.00
# 2             $107,000.00
# 3             $107,000.00
# 4             $107,000.00
# 5             $106,000.00
# 6             $105,000.00
# 7             $104,000.00
# 8             $104,000.00
# 9             $104,000.00

# %%
ivies.head(10)
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
#Concatenate eng and ivies using the Pandas concatination function and give the shape of your dataframes
pd.concat([eng,ivies]).shape
# Out:
# (27, 4)

# %%
#Concatenate the 5 dataframes and drop the duplicated values of 'School Name' in your output dataframe called schools
# initialize and empty dataFrame schools
schools = ({})
schools = pd.concat([eng,state,party,liberal,ivies])
schools.drop_duplicates(subset="School Name",keep=False, inplace=True)  # removing all duplicate values.
print(schools)
# Out:
#                                      School Name  School Type  \
# 0    Massachusetts Institute of Technology (MIT)  Engineering
# 1       California Institute of Technology (CIT)  Engineering
# 2                            Harvey Mudd College  Engineering
# 3   Polytechnic University of New York, Brooklyn  Engineering
# 4                                   Cooper Union  Engineering
# ..                                           ...          ...
# 3                             Harvard University   Ivy League
# 4                     University of Pennsylvania   Ivy League
# 5                             Cornell University   Ivy League
# 6                               Brown University   Ivy League
# 7                            Columbia University   Ivy League
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $62,400.00              $114,000.00
# 4             $62,200.00              $114,000.00
# ..                    ...                      ...
# 3             $63,400.00              $124,000.00
# 4             $60,900.00              $120,000.00
# 5             $60,300.00              $110,000.00
# 6             $56,200.00              $109,000.00
# 7             $59,400.00              $107,000.00
#
# [229 rows x 4 columns]

# %%
#Explain what this code implements when run.
schools.loc[0]
print("loc attribute allows indexing and slicing that always references the explicit index.\nThus all rows with index 0 are returned. In this case 4 rows are returned whose index was 0")
# Out:
# loc attribute allows indexing and slicing that always references the explicit index.
# Thus all rows with index 0 are returned. In this case 4 rows are returned whose index was 0

# %%
#Check if the index in schools is diplicated or not
if schools.index.is_unique:
  print(" Index in school are not duplicate")
else:
  print(" Index in school are duplicate")
# Out:
#  Index in school are duplicate

# %%
# Does coding and running schools.loc[0:2] work? and why?
print("This gives an error because there are multiple rows with same index. So the loc attribute does not know which one to pick")
# Out:
# This gives an error because there are multiple rows with same index. So the loc attribute does not know which one to pick

# %%
#Explain how to fix the duplicated index problem.
print("One way is to ignore the index using ignore_index  option.")
print("Another option is to use Multiindex;\nthe result will be a hierarchically indexed series containing the data")
# Out:
# One way is to ignore the index using ignore_index  option.
# Another option is to use Multiindex;
# the result will be a hierarchically indexed series containing the data

# %%
# Create eng2 and ivies2 from eng and ivies where the index is Set to 'School Name'.
eng2 = eng.set_index('School Name')
eng2
# Out:
#                                                     School Type  \
# School Name
# Massachusetts Institute of Technology (MIT)         Engineering
# California Institute of Technology (CIT)            Engineering
# Harvey Mudd College                                 Engineering
# Polytechnic University of New York, Brooklyn        Engineering
# Cooper Union                                        Engineering
# Worcester Polytechnic Institute (WPI)               Engineering
# Carnegie Mellon University (CMU)                    Engineering
# Rensselaer Polytechnic Institute (RPI)              Engineering
# Georgia Institute of Technology                     Engineering
# Colorado School of Mines                            Engineering
# Stevens Institute of Technology                     Engineering
# Illinois Institute of Technology (IIT)              Engineering
# Wentworth Institute of Technology                   Engineering
# Virginia Polytechnic Institute and State Univer...  Engineering
# South Dakota School of Mines & Technology           Engineering
# New Mexico Institute of Mining and Technology (...  Engineering
# Rochester Institute of Technology (RIT)             Engineering
# Embry-Riddle Aeronautical University (ERAU)         Engineering
# Tennessee Technological University                  Engineering
#
#                                                    Starting Median Salary  \
# School Name
# Massachusetts Institute of Technology (MIT)                   $72,200.00
# California Institute of Technology (CIT)                      $75,500.00
# Harvey Mudd College                                           $71,800.00
# Polytechnic University of New York, Brooklyn                  $62,400.00
# Cooper Union                                                  $62,200.00
# Worcester Polytechnic Institute (WPI)                         $61,000.00
# Carnegie Mellon University (CMU)                              $61,800.00
# Rensselaer Polytechnic Institute (RPI)                        $61,100.00
# Georgia Institute of Technology                               $58,300.00
# Colorado School of Mines                                      $58,100.00
# Stevens Institute of Technology                               $60,600.00
# Illinois Institute of Technology (IIT)                        $56,000.00
# Wentworth Institute of Technology                             $53,000.00
# Virginia Polytechnic Institute and State Univer...            $53,500.00
# South Dakota School of Mines & Technology                     $55,800.00
# New Mexico Institute of Mining and Technology (...            $51,000.00
# Rochester Institute of Technology (RIT)                       $48,900.00
# Embry-Riddle Aeronautical University (ERAU)                   $52,700.00
# Tennessee Technological University                            $46,200.00
#
#                                                    Mid-Career Median Salary
# School Name
# Massachusetts Institute of Technology (MIT)                    $126,000.00
# California Institute of Technology (CIT)                       $123,000.00
# Harvey Mudd College                                            $122,000.00
# Polytechnic University of New York, Brooklyn                   $114,000.00
# Cooper Union                                                   $114,000.00
# Worcester Polytechnic Institute (WPI)                          $114,000.00
# Carnegie Mellon University (CMU)                               $111,000.00
# Rensselaer Polytechnic Institute (RPI)                         $110,000.00
# Georgia Institute of Technology                                $106,000.00
# Colorado School of Mines                                       $106,000.00
# Stevens Institute of Technology                                $105,000.00
# Illinois Institute of Technology (IIT)                          $97,800.00
# Wentworth Institute of Technology                               $96,700.00
# Virginia Polytechnic Institute and State Univer...              $95,400.00
# South Dakota School of Mines & Technology                       $93,400.00
# New Mexico Institute of Mining and Technology (...              $93,400.00
# Rochester Institute of Technology (RIT)                         $84,600.00
# Embry-Riddle Aeronautical University (ERAU)                     $80,700.00
# Tennessee Technological University                              $80,000.00

# %%
ivies2 = ivies.set_index('School Name')
ivies2
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Dartmouth College           Ivy League            $58,000.00
# Princeton University        Ivy League            $66,500.00
# Yale University             Ivy League            $59,100.00
# Harvard University          Ivy League            $63,400.00
# University of Pennsylvania  Ivy League            $60,900.00
# Cornell University          Ivy League            $60,300.00
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
#
#                            Mid-Career Median Salary
# School Name
# Dartmouth College                      $134,000.00
# Princeton University                   $131,000.00
# Yale University                        $126,000.00
# Harvard University                     $124,000.00
# University of Pennsylvania             $120,000.00
# Cornell University                     $110,000.00
# Brown University                       $109,000.00
# Columbia University                    $107,000.00

# %%
#Concatenate eng and ivies by using the multi-index in order to remove the duplicated index issue.
pd.concat([eng,ivies], keys=['eng','ivies'])
# Out:
#                                                 School Name  School Type  \
# eng   0         Massachusetts Institute of Technology (MIT)  Engineering
#       1            California Institute of Technology (CIT)  Engineering
#       2                                 Harvey Mudd College  Engineering
#       3        Polytechnic University of New York, Brooklyn  Engineering
#       4                                        Cooper Union  Engineering
#       5               Worcester Polytechnic Institute (WPI)  Engineering
#       6                    Carnegie Mellon University (CMU)  Engineering
#       7              Rensselaer Polytechnic Institute (RPI)  Engineering
#       8                     Georgia Institute of Technology  Engineering
#       9                            Colorado School of Mines  Engineering
#       10                    Stevens Institute of Technology  Engineering
#       11             Illinois Institute of Technology (IIT)  Engineering
#       12                  Wentworth Institute of Technology  Engineering
#       13  Virginia Polytechnic Institute and State Unive...  Engineering
#       14          South Dakota School of Mines & Technology  Engineering
#       15  New Mexico Institute of Mining and Technology ...  Engineering
#       16            Rochester Institute of Technology (RIT)  Engineering
#       17        Embry-Riddle Aeronautical University (ERAU)  Engineering
#       18                 Tennessee Technological University  Engineering
# ivies 0                                   Dartmouth College   Ivy League
#       1                                Princeton University   Ivy League
#       2                                     Yale University   Ivy League
#       3                                  Harvard University   Ivy League
#       4                          University of Pennsylvania   Ivy League
#       5                                  Cornell University   Ivy League
#       6                                    Brown University   Ivy League
#       7                                 Columbia University   Ivy League
#
#          Starting Median Salary Mid-Career Median Salary
# eng   0             $72,200.00              $126,000.00
#       1             $75,500.00              $123,000.00
#       2             $71,800.00              $122,000.00
#       3             $62,400.00              $114,000.00
#       4             $62,200.00              $114,000.00
#       5             $61,000.00              $114,000.00
#       6             $61,800.00              $111,000.00
#       7             $61,100.00              $110,000.00
#       8             $58,300.00              $106,000.00
#       9             $58,100.00              $106,000.00
#       10            $60,600.00              $105,000.00
#       11            $56,000.00               $97,800.00
#       12            $53,000.00               $96,700.00
#       13            $53,500.00               $95,400.00
#       14            $55,800.00               $93,400.00
#       15            $51,000.00               $93,400.00
#       16            $48,900.00               $84,600.00
#       17            $52,700.00               $80,700.00
#       18            $46,200.00               $80,000.00
# ivies 0             $58,000.00              $134,000.00
#       1             $66,500.00              $131,000.00
#       2             $59,100.00              $126,000.00
#       3             $63,400.00              $124,000.00
#       4             $60,900.00              $120,000.00
#       5             $60,300.00              $110,000.00
#       6             $56,200.00              $109,000.00
#       7             $59,400.00              $107,000.00

# %%
#Use the append function to concatenate 'liberal' and 'party' dataframes
liberal.append(party)
# Out:
#                           School Name   School Type Starting Median Salary  \
# 0                 Bucknell University  Liberal Arts            $54,100.00
# 1                  Colgate University  Liberal Arts            $52,800.00
# 2                     Amherst College  Liberal Arts            $54,500.00
# 3                   Lafayette College  Liberal Arts            $53,900.00
# 4                     Bowdoin College  Liberal Arts            $48,100.00
# ..                                ...           ...                    ...
# 15  University of New Hampshire (UNH)         Party            $41,800.00
# 16     West Virginia University (WVU)         Party            $43,100.00
# 17            University of Tennessee         Party            $43,800.00
# 18                    Ohio University         Party            $42,200.00
# 19     Florida State University (FSU)         Party            $42,100.00
#
#    Mid-Career Median Salary
# 0              $110,000.00
# 1              $108,000.00
# 2              $107,000.00
# 3              $107,000.00
# 4              $107,000.00
# ..                      ...
# 15              $78,300.00
# 16              $78,100.00
# 17              $74,600.00
# 18              $73,400.00
# 19              $73,000.00
#
# [67 rows x 4 columns]

# %%
regions_url = 'https://andybek.com/pandas-regions'

# %%
# Create the dataframe 'regions'  
regions = pd.read_csv(regions_url)
regions
# Out:
#                                       School Name        Region
# 0     Massachusetts Institute of Technology (MIT)  Northeastern
# 1        California Institute of Technology (CIT)    California
# 2                             Harvey Mudd College    California
# 3    Polytechnic University of New York, Brooklyn  Northeastern
# 4                                    Cooper Union  Northeastern
# ..                                            ...           ...
# 264                  Austin Peay State University      Southern
# 265                    Pittsburg State University    Midwestern
# 266                      Southern Utah University       Western
# 267           Montana State University - Billings       Western
# 268                  Black Hills State University    Midwestern
#
# [269 rows x 2 columns]

# %%
# Merge the 2 dataframes schools and regions
pd.merge(schools,regions)
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 224                            Harvard University   Ivy League
# 225                    University of Pennsylvania   Ivy League
# 226                            Cornell University   Ivy League
# 227                              Brown University   Ivy League
# 228                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0              $72,200.00              $126,000.00   Northeastern
# 1              $75,500.00              $123,000.00     California
# 2              $71,800.00              $122,000.00     California
# 3              $62,400.00              $114,000.00   Northeastern
# 4              $62,200.00              $114,000.00   Northeastern
# ..                     ...                      ...           ...
# 224            $63,400.00              $124,000.00   Northeastern
# 225            $60,900.00              $120,000.00   Northeastern
# 226            $60,300.00              $110,000.00   Northeastern
# 227            $56,200.00              $109,000.00   Northeastern
# 228            $59,400.00              $107,000.00   Northeastern
#
# [229 rows x 5 columns]

# %%
# Merge schools and regions on the column name 'School Name'
pd.merge(schools,regions,on='School Name')
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 224                            Harvard University   Ivy League
# 225                    University of Pennsylvania   Ivy League
# 226                            Cornell University   Ivy League
# 227                              Brown University   Ivy League
# 228                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0              $72,200.00              $126,000.00   Northeastern
# 1              $75,500.00              $123,000.00     California
# 2              $71,800.00              $122,000.00     California
# 3              $62,400.00              $114,000.00   Northeastern
# 4              $62,200.00              $114,000.00   Northeastern
# ..                     ...                      ...           ...
# 224            $63,400.00              $124,000.00   Northeastern
# 225            $60,900.00              $120,000.00   Northeastern
# 226            $60,300.00              $110,000.00   Northeastern
# 227            $56,200.00              $109,000.00   Northeastern
# 228            $59,400.00              $107,000.00   Northeastern
#
# [229 rows x 5 columns]

# %%
income_url = 'https://andybek.com/pandas-mid'

# %%
#Create Dataframe (mid_career) from the file income 
mid_career = pd.read_csv(income_url)
mid_career
# Out:
#                                       school_name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 264                  Austin Peay State University
# 265                    Pittsburg State University
# 266                      Southern Utah University
# 267           Montana State University - Billings
# 268                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# 4                                 NaN                       $80,200.00
# ..                                ...                               ...
# 264                       $32,200.00                        $40,500.00
# 265                       $25,600.00                        $46,000.00
# 266                       $30,700.00                        $39,700.00
# 267                       $22,600.00                        $31,800.00
# 268                       $27,000.00                        $32,200.00
#
#     Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                        $168,000.00                       $220,000.00
# 1                        $161,000.00                                NaN
# 2                        $180,000.00                                NaN
# 3                        $143,000.00                       $190,000.00
# 4                        $142,000.00                                NaN
# ..                                ...                               ...
# 264                       $73,900.00                        $96,200.00
# 265                       $84,600.00                       $117,000.00
# 266                       $78,400.00                       $116,000.00
# 267                       $78,500.00                        $98,900.00
# 268                       $60,900.00                        $87,600.00
#
# [269 rows x 5 columns]

# %%
# Merge mid_career and schools on the arguments left_on and right_on and drop the duplicated column. 
pd.merge(mid_career,schools,left_on='school_name',right_on='School Name').drop('School Name', axis=1)
# Out:
#                                       school_name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 224                  Austin Peay State University
# 225                    Pittsburg State University
# 226                      Southern Utah University
# 227           Montana State University - Billings
# 228                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# 4                                 NaN                       $80,200.00
# ..                                ...                               ...
# 224                       $32,200.00                        $40,500.00
# 225                       $25,600.00                        $46,000.00
# 226                       $30,700.00                        $39,700.00
# 227                       $22,600.00                        $31,800.00
# 228                       $27,000.00                        $32,200.00
#
#     Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary  \
# 0                        $168,000.00                       $220,000.00
# 1                        $161,000.00                                NaN
# 2                        $180,000.00                                NaN
# 3                        $143,000.00                       $190,000.00
# 4                        $142,000.00                                NaN
# ..                                ...                               ...
# 224                       $73,900.00                        $96,200.00
# 225                       $84,600.00                       $117,000.00
# 226                       $78,400.00                       $116,000.00
# 227                       $78,500.00                        $98,900.00
# 228                       $60,900.00                        $87,600.00
#
#      School Type Starting Median Salary Mid-Career Median Salary
# 0    Engineering            $72,200.00              $126,000.00
# 1    Engineering            $75,500.00              $123,000.00
# 2    Engineering            $71,800.00              $122,000.00
# 3    Engineering            $62,400.00              $114,000.00
# 4    Engineering            $62,200.00              $114,000.00
# ..           ...                    ...                      ...
# 224        State            $37,700.00               $59,200.00
# 225        State            $40,400.00               $58,200.00
# 226        State            $41,900.00               $56,500.00
# 227        State            $37,900.00               $50,600.00
# 228        State            $35,300.00               $43,900.00
#
# [229 rows x 8 columns]

# %% [markdown]
# Q1: Concatenate the *liberal* and *state* schools into a new dataframe. How many unique school names are there?

# %%
#Q1:Code
new_df = ({})
new_df = pd.concat([liberal,state])
new_df["School Name"].unique().size
# Out:
# 222

# %% [markdown]
# Q2: What is the average median starting salary in the dataframe created above?

# %%
#Q2:Code
#CONVERT STRING TO INTEGER TO GET THE MEAN VALUE.
def return_integer(value):
  return int(value[1:-4].strip().replace(',',''))
new_df["Starting Median Salary"] = new_df["Starting Median Salary"].apply(return_integer)
new_df["Starting Median Salary"].mean()
# Out:
# 44469.36936936937

# %% [markdown]
# Q3: Create a short dataframe that shows the top 3 *liberal* arts and *state* schools that produce the highest (mid-career) earning graduates.
#
# Show the *School Name* and *Mid-Career Median Salary* columns from each dataset, side by side, i.e. <ins>horizontally</ins>.
#
# Nest the column labels within 'Liberal Arts' and 'State' labels.

# %%
#Q3:Code
class display(object):
    """Display HTML representation of multiple objects"""
    template = """<div style="float: left; padding: 10px;">
    <p style='font-family:"Courier New", Courier, monospace'>{0}</p>{1}
    </div>"""
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)
    
    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)

top3_liberal = liberal.sort_values(by=['Mid-Career Median Salary'], ascending=False).head(3)
top3_liberal = top3_liberal[['School Name','Mid-Career Median Salary']]
top3_state = state.sort_values(by=['Mid-Career Median Salary'], ascending=False).head(3)
top3_state = top3_state[['School Name','Mid-Career Median Salary']]

display('top3_liberal','top3_state')

# pd.concat([top3_liberal,top3_state],axis=1)
display('top3_liberal','top3_state')
# Out:
# top3_liberal
#                                       School Name Mid-Career Median Salary
# 13  Wesleyan University (Middletown, Connecticut)              $97,900.00
# 14                                  Bates College              $96,500.00
# 15                                  Union College              $95,800.00
#
# top3_state
#                               School Name Mid-Career Median Salary
# 5         University of California, Davis              $99,600.00
# 6  University of Colorado - Boulder (UCB)              $97,600.00
# 7  University of California, Irvine (UCI)              $96,700.00

# %% [markdown]
# Q4: Merge *liberal* arts schools with *regions* and assign the resulting dataframe to *dfm*. What region has the highest number of liberal arts schools?

# %%
#Q4:Code
dfm = pd.merge(liberal,regions)
dfm.groupby(['Region']).size()
# Out:
# Region
# California       3
# Midwestern       8
# Northeastern    25
# Southern         5
# Western          7
# dtype: int64

# %%
print("Thus we can see that Northeastern has the highest number of libreal arts school")
# Out:
# Thus we can see that Northeastern has the highest number of libreal arts school

# %% [markdown]
# Q5: Set *school_name* as the index of the *mid_career* dataframe. Do the operation inplace.

# %%
#Q5:Code
mid_career.set_index('school_name',inplace=True)

# %% [markdown]
# Q6: Merge the *dfm* and *mid_career* dataframes. Is the join operation one-to-one?

# %%
#Q6:Code
pd.merge(dfm,mid_career,right_index=True,left_on='School Name')
# Out:
#                                       School Name   School Type  \
# 0                             Bucknell University  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 2                                 Amherst College  Liberal Arts
# 3                               Lafayette College  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 6                              Occidental College  Liberal Arts
# 7                   Washington and Lee University  Liberal Arts
# 8                              Swarthmore College  Liberal Arts
# 9                                Davidson College  Liberal Arts
# 10                               Carleton College  Liberal Arts
# 11                               Williams College  Liberal Arts
# 12                                 Pomona College  Liberal Arts
# 13  Wesleyan University (Middletown, Connecticut)  Liberal Arts
# 14                                  Bates College  Liberal Arts
# 15                                  Union College  Liberal Arts
# 16                         University of Richmond  Liberal Arts
# 17                                 Vassar College  Liberal Arts
# 18                             Middlebury College  Liberal Arts
# 19                          Mount Holyoke College  Liberal Arts
# 20                  Franklin and Marshall College  Liberal Arts
# 21                              DePauw University  Liberal Arts
# 22                               St. Olaf College  Liberal Arts
# 23                                  Colby College  Liberal Arts
# 24                             Gettysburg College  Liberal Arts
# 25                                  Siena College  Liberal Arts
# 26                                  Smith College  Liberal Arts
# 27                               Hamilton College  Liberal Arts
# 28                         Randolph-Macon College  Liberal Arts
# 28                         Randolph-Macon College  Liberal Arts
# 29                         Randolph-Macon College  Liberal Arts
# 29                         Randolph-Macon College  Liberal Arts
# 30                              Wellesley College  Liberal Arts
# 31                             Denison University  Liberal Arts
# 32                                Oberlin College  Liberal Arts
# 33                      University of Puget Sound  Liberal Arts
# 34                          Colorado College (CC)  Liberal Arts
# 35                                   Reed College  Liberal Arts
# 36                      Gustavus Adolphus College  Liberal Arts
# 37                                Whitman College  Liberal Arts
# 38                                Ursinus College  Liberal Arts
# 39                                Juniata College  Liberal Arts
# 40                          Wittenberg University  Liberal Arts
# 41                               Grinnell College  Liberal Arts
# 42                               Skidmore College  Liberal Arts
# 43                               Moravian College  Liberal Arts
# 44                          Lewis & Clark College  Liberal Arts
# 45                             Fort Lewis College  Liberal Arts
# 46                         Thomas Aquinas College  Liberal Arts
# 47                        Evergreen State College  Liberal Arts
#
#    Starting Median Salary Mid-Career Median Salary        Region  \
# 0             $54,100.00              $110,000.00   Northeastern
# 1             $52,800.00              $108,000.00   Northeastern
# 2             $54,500.00              $107,000.00   Northeastern
# 3             $53,900.00              $107,000.00   Northeastern
# 4             $48,100.00              $107,000.00   Northeastern
# 5             $50,200.00              $106,000.00   Northeastern
# 6             $51,900.00              $105,000.00     California
# 7             $53,600.00              $104,000.00       Southern
# 8             $49,700.00              $104,000.00   Northeastern
# 9             $46,100.00              $104,000.00       Southern
# 10            $47,500.00              $103,000.00     Midwestern
# 11            $51,700.00              $102,000.00   Northeastern
# 12            $48,600.00              $101,000.00     California
# 13            $46,500.00               $97,900.00   Northeastern
# 14            $47,300.00               $96,500.00   Northeastern
# 15            $47,200.00               $95,800.00   Northeastern
# 16            $48,600.00               $94,600.00       Southern
# 17            $46,000.00               $94,600.00   Northeastern
# 18            $47,700.00               $94,200.00   Northeastern
# 19            $42,400.00               $94,100.00   Northeastern
# 20            $49,100.00               $92,800.00   Northeastern
# 21            $41,400.00               $88,300.00     Midwestern
# 22            $45,300.00               $86,200.00     Midwestern
# 23            $46,400.00               $85,800.00   Northeastern
# 24            $44,700.00               $85,800.00   Northeastern
# 25            $45,500.00               $85,200.00   Northeastern
# 26            $44,000.00               $83,900.00   Northeastern
# 27            $49,200.00               $83,700.00   Northeastern
# 28            $42,600.00               $83,600.00       Southern
# 28            $42,600.00               $83,600.00       Southern
# 29            $42,600.00               $83,600.00       Southern
# 29            $42,600.00               $83,600.00       Southern
# 30            $42,800.00               $83,500.00   Northeastern
# 31            $42,000.00               $83,500.00     Midwestern
# 32            $43,400.00               $81,600.00     Midwestern
# 33            $46,600.00               $81,500.00        Western
# 34            $38,500.00               $81,400.00        Western
# 35            $40,500.00               $81,100.00        Western
# 36            $44,500.00               $80,600.00     Midwestern
# 37            $43,500.00               $80,100.00        Western
# 38            $42,100.00               $80,000.00   Northeastern
# 39            $41,800.00               $78,900.00   Northeastern
# 40            $39,200.00               $78,200.00     Midwestern
# 41            $42,600.00               $76,600.00     Midwestern
# 42            $41,600.00               $74,600.00   Northeastern
# 43            $42,500.00               $74,400.00   Northeastern
# 44            $38,900.00               $72,600.00        Western
# 45            $42,000.00               $69,800.00        Western
# 46            $41,500.00               $67,500.00     California
# 47            $39,500.00               $63,900.00        Western
#
#    Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $62,800.00                        $80,600.00
# 1                        $60,000.00                        $76,700.00
# 2                                NaN                       $84,900.00
# 3                        $70,600.00                        $79,300.00
# 4                                NaN                       $74,600.00
# 5                                NaN                       $65,600.00
# 6                                NaN                       $54,800.00
# 7                                NaN                       $82,800.00
# 8                                NaN                       $67,200.00
# 9                                NaN                       $70,500.00
# 10                               NaN                       $69,400.00
# 11                               NaN                       $76,400.00
# 12                               NaN                       $63,300.00
# 13                       $42,000.00                        $62,500.00
# 14                               NaN                       $60,700.00
# 15                       $48,700.00                        $75,200.00
# 16                       $44,500.00                        $59,400.00
# 17                               NaN                       $60,600.00
# 18                               NaN                       $69,100.00
# 19                               NaN                       $57,100.00
# 20                               NaN                       $55,800.00
# 21                       $49,500.00                        $57,400.00
# 22                       $41,300.00                        $61,000.00
# 23                               NaN                       $63,500.00
# 24                               NaN                       $66,300.00
# 25                       $38,700.00                        $58,400.00
# 26                       $45,100.00                        $59,800.00
# 27                               NaN                       $51,900.00
# 28                               NaN                       $54,100.00
# 28                               NaN                       $54,100.00
# 29                               NaN                       $54,100.00
# 29                               NaN                       $54,100.00
# 30                               NaN                       $58,600.00
# 31                               NaN                       $62,100.00
# 32                               NaN                       $46,400.00
# 33                       $48,900.00                        $60,100.00
# 34                               NaN                       $43,000.00
# 35                               NaN                       $67,400.00
# 36                               NaN                       $49,300.00
# 37                               NaN                       $64,800.00
# 38                       $35,600.00                        $54,300.00
# 39                               NaN                       $67,200.00
# 40                               NaN                       $54,100.00
# 41                               NaN                       $65,100.00
# 42                               NaN                       $42,800.00
# 43                               NaN                       $56,700.00
# 44                       $38,200.00                        $53,400.00
# 45                               NaN                       $55,000.00
# 46                               NaN                       $44,600.00
# 47                       $38,800.00                        $47,200.00
#
#    Mid-Career 75th Percentile Salary Mid-Career 90th Percentile Salary
# 0                       $156,000.00                       $251,000.00
# 1                       $167,000.00                       $265,000.00
# 2                       $162,000.00                                NaN
# 3                       $144,000.00                       $204,000.00
# 4                       $146,000.00                                NaN
# 5                       $143,000.00                                NaN
# 6                       $157,000.00                                NaN
# 7                       $146,000.00                                NaN
# 8                       $167,000.00                                NaN
# 9                       $146,000.00                                NaN
# 10                      $141,000.00                                NaN
# 11                      $143,000.00                                NaN
# 12                      $161,000.00                                NaN
# 13                      $126,000.00                       $215,000.00
# 14                      $162,000.00                                NaN
# 15                      $135,000.00                       $230,000.00
# 16                      $151,000.00                       $211,000.00
# 17                      $123,000.00                                NaN
# 18                      $129,000.00                                NaN
# 19                      $131,000.00                                NaN
# 20                      $185,000.00                                NaN
# 21                      $133,000.00                       $185,000.00
# 22                      $120,000.00                       $185,000.00
# 23                      $129,000.00                                NaN
# 24                      $132,000.00                                NaN
# 25                      $129,000.00                       $189,000.00
# 26                      $129,000.00                       $184,000.00
# 27                      $123,000.00                                NaN
# 28                      $123,000.00                                NaN
# 28                      $123,000.00                                NaN
# 29                      $123,000.00                                NaN
# 29                      $123,000.00                                NaN
# 30                      $125,000.00                                NaN
# 31                      $122,000.00                                NaN
# 32                      $128,000.00                                NaN
# 33                      $104,000.00                       $137,000.00
# 34                      $148,000.00                                NaN
# 35                      $101,000.00                                NaN
# 36                      $101,000.00                                NaN
# 37                      $111,000.00                                NaN
# 38                      $100,000.00                       $160,000.00
# 39                      $110,000.00                                NaN
# 40                      $131,000.00                                NaN
# 41                      $116,000.00                                NaN
# 42                      $147,000.00                                NaN
# 43                       $94,900.00                                NaN
# 44                      $104,000.00                       $140,000.00
# 45                       $94,000.00                                NaN
# 46                       $93,100.00                                NaN
# 47                       $91,600.00                       $120,000.00

# %%
print("yes its one to one join function")
# Out:
# yes its one to one join function

# %% [markdown]
# Create dataframe games

# %%
#Dataframe creation
games_url = 'https://andybek.com/pandas-games'
games = pd.read_csv(games_url)
games
# Out:
#                                 Name Platform    Year         Genre  \
# 0                 Kinect Adventures!     X360  2010.0          Misc
# 1                 Grand Theft Auto V      PS3  2013.0        Action
# 2                 Grand Theft Auto V     X360  2013.0        Action
# 3     Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# 4            Call of Duty: Black Ops     X360  2010.0       Shooter
# ...                              ...      ...     ...           ...
# 3138                  Bound By Flame     X360  2014.0  Role-Playing
# 3139                    Mighty No. 9     XOne  2016.0      Platform
# 3140              Resident Evil 4 HD     XOne  2016.0       Shooter
# 3141   Farming 2017 - The Simulation      PS4  2016.0    Simulation
# 3142               Rugby Challenge 3     XOne  2016.0        Sports
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0     Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1       Take-Two Interactive      7.01      9.27      0.97         4.14
# 2       Take-Two Interactive      9.63      5.31      0.06         1.38
# 3                 Activision      9.03      4.28      0.13         1.32
# 4                 Activision      9.67      3.73      0.11         1.13
# ...                      ...       ...       ...       ...          ...
# 3138                     NaN      0.00      0.01      0.00         0.00
# 3139             Deep Silver      0.01      0.00      0.00         0.00
# 3140                  Capcom      0.01      0.00      0.00         0.00
# 3141       UIG Entertainment      0.00      0.01      0.00         0.00
# 3142    Alternative Software      0.00      0.01      0.00         0.00
#
#       Global_Sales
# 0            21.82
# 1            21.40
# 2            16.38
# 3            14.76
# 4            14.64
# ...            ...
# 3138          0.01
# 3139          0.01
# 3140          0.01
# 3141          0.01
# 3142          0.01
#
# [3143 rows x 10 columns]

# %% [markdown]
# Q7: What are the total sales across all regions?

# %%
#Q7-Code
games['Global_Sales'].sum()
# Out:
# 2356.96

# %%
games.tail(10)
# Out:
#                                                    Name Platform    Year  \
# 3133                           Sébastien Loeb Rally Evo     XOne  2016.0
# 3134                                      Hitman (2016)     XOne  2016.0
# 3135                        Metal Gear Solid HD Edition     X360  2011.0
# 3136                                    Battle Fantasia      PS3  2008.0
# 3137  God Eater Off Shot: Tachibana Sakuya-hen Twin ...      PS4  2016.0
# 3138                                     Bound By Flame     X360  2014.0
# 3139                                       Mighty No. 9     XOne  2016.0
# 3140                                 Resident Evil 4 HD     XOne  2016.0
# 3141                      Farming 2017 - The Simulation      PS4  2016.0
# 3142                                  Rugby Challenge 3     XOne  2016.0
#
#              Genre                     Publisher  NA_Sales  EU_Sales  \
# 3133        Racing               Milestone S.r.l      0.00      0.01
# 3134        Action                   Square Enix      0.00      0.01
# 3135        Action  Konami Digital Entertainment      0.00      0.00
# 3136      Fighting                     505 Games      0.00      0.00
# 3137        Action            Namco Bandai Games      0.00      0.00
# 3138  Role-Playing                           NaN      0.00      0.01
# 3139      Platform                   Deep Silver      0.01      0.00
# 3140       Shooter                        Capcom      0.01      0.00
# 3141    Simulation             UIG Entertainment      0.00      0.01
# 3142        Sports          Alternative Software      0.00      0.01
#
#       JP_Sales  Other_Sales  Global_Sales
# 3133      0.00          0.0          0.01
# 3134      0.00          0.0          0.01
# 3135      0.01          0.0          0.01
# 3136      0.01          0.0          0.01
# 3137      0.01          0.0          0.01
# 3138      0.00          0.0          0.01
# 3139      0.00          0.0          0.01
# 3140      0.00          0.0          0.01
# 3141      0.00          0.0          0.01
# 3142      0.00          0.0          0.01

# %% [markdown]
#  Q8: Find the total sales by region for X360 and PS3.

# %%
#8-Code
new_games = games[(games["Platform"] == 'X360') | (games["Platform"] == 'PS3')]
new_games = new_games[['Platform','Global_Sales']]
new_games.groupby(['Platform']).sum()
# Out:
#           Global_Sales
# Platform
# PS3             957.84
# X360            979.96

# %% [markdown]
# Q9: How much does each platform sell across regions, on average?

# %%
#Q9-Code
new_games2 = games[['EU_Sales','NA_Sales','JP_Sales','Other_Sales','Global_Sales','Platform']]
new_games2.groupby(['Platform']).aggregate('mean')
# Out:
#           EU_Sales  NA_Sales  JP_Sales  Other_Sales  Global_Sales
# Platform
# PS3       0.258623  0.295154  0.060188     0.106795      0.720722
# PS4       0.368155  0.288095  0.042560     0.129048      0.827679
# X360      0.221802  0.475138  0.009826     0.067621      0.774672
# XOne      0.214319  0.390563  0.001596     0.055962      0.662254

# %% [markdown]
# Q10: Create a smaller dataframe from *games*, selecting only the Publisher, Genre, Platform, and NA_Sales columns. Assign this dataframe to the variable *publishers*.

# %%
#Q10-Code
publishers = games[['Publisher','Genre','Platform','NA_Sales']]
publishers
# Out:
#                    Publisher         Genre Platform  NA_Sales
# 0     Microsoft Game Studios          Misc     X360     14.97
# 1       Take-Two Interactive        Action      PS3      7.01
# 2       Take-Two Interactive        Action     X360      9.63
# 3                 Activision       Shooter     X360      9.03
# 4                 Activision       Shooter     X360      9.67
# ...                      ...           ...      ...       ...
# 3138                     NaN  Role-Playing     X360      0.00
# 3139             Deep Silver      Platform     XOne      0.01
# 3140                  Capcom       Shooter     XOne      0.01
# 3141       UIG Entertainment    Simulation      PS4      0.00
# 3142    Alternative Software        Sports     XOne      0.00
#
# [3143 rows x 4 columns]

# %% [markdown]
# Q11: From the *publishers* dataframe, find the top 10 game publishers in North America by total sales.

# %%
#Q11-Code
NA_Sales_df = publishers.groupby("Publisher")["NA_Sales"].sum().reset_index()
NA_Sales_df.sort_values(by = "NA_Sales", ascending=False).head(10)
# Out:
#                                   Publisher  NA_Sales
# 41                          Electronic Arts    213.38
# 6                                Activision    193.16
# 130                    Take-Two Interactive    120.99
# 85                   Microsoft Game Studios    116.77
# 139                                 Ubisoft     98.65
# 117             Sony Computer Entertainment     76.35
# 147  Warner Bros. Interactive Entertainment     45.24
# 128                                     THQ     36.44
# 19                       Bethesda Softworks     33.88
# 23                                   Capcom     24.74

# %% [markdown]
# Q12: What is the gaming platform that has attracted the most sales in North America?

# %%
#Q12:Code
Platform_NA_Sales = publishers.groupby("Platform")["NA_Sales"].sum().reset_index()
Platform_NA_Sales.sort_values(by="NA_Sales", ascending=False).head(1)
# Out:
#   Platform  NA_Sales
# 2     X360    601.05

# %%
#Create Dataframe sat 
sat_url = 'https://andybek.com/pandas-sat'
sat = pd.read_csv(sat_url)
sat
# Out:
#                                      School Name    Borough  \
# 0          A. Philip Randolph Campus High School  Manhattan
# 1          A. Philip Randolph Campus High School  Manhattan
# 2          A. Philip Randolph Campus High School  Manhattan
# 3                    Abraham Lincoln High School   Brooklyn
# 4                    Abraham Lincoln High School   Brooklyn
# ...                                          ...        ...
# 1120  Young Women's Leadership School in Astoria     Queens
# 1121  Young Women's Leadership School in Astoria     Queens
# 1122   Young Women's Leadership School in Queens     Queens
# 1123   Young Women's Leadership School in Queens     Queens
# 1124   Young Women's Leadership School in Queens     Queens
#
#       Student Enrollment Percent Tested SAT Section  Score
# 0                   1354         74.00%        Math    459
# 1                   1354         74.00%     Reading    453
# 2                   1354         74.00%     Writing    447
# 3                   2341         54.90%        Math    441
# 4                   2341         54.90%     Reading    422
# ...                  ...            ...         ...    ...
# 1120                 572        100.00%     Reading    464
# 1121                 572        100.00%     Writing    477
# 1122                 557         90.40%        Math    415
# 1123                 557         90.40%     Reading    420
# 1124                 557         90.40%     Writing    433
#
# [1125 rows x 6 columns]

# %% [markdown]
# Q13: Starting with our main dataframe (*sat*), create a pivot table that summarizes the <ins>total</ins> student enrollment (Student Enrollment) across all 5 boroughs (*Borough*).
#
# Which boroughs have the highest and lowest high school student bodies?

# %%
#Q13
table = pd.pivot_table(sat,values = 'Student Enrollment', index= 'Borough', aggfunc=np.sum)
print(table)
print("highest school students bodies : ",table.idxmax()[0])
print("lowest school students bodies : " , table.idxmin()[0])
# Out:
#                Student Enrollment
# Borough
# Bronx                      159267
# Brooklyn                   242814
# Manhattan                  170370
# Queens                     232437
# Staten Island               55380
# highest school students bodies :  Brooklyn
# lowest school students bodies :  Staten Island

# %% [markdown]
# Q14: Modify the pivot table from the step above to also reflect the average student body size (*Student Enrollment*) across boroughs, in the same pivot table.

# %%
#Q14
pd.pivot_table(sat,values='Student Enrollment', index='Borough', aggfunc={'Student Enrollment':[np.sum,np.mean]})
# Out:
#                       mean       sum
# Borough
# Bronx           541.724490  159267.0
# Brooklyn        742.550459  242814.0
# Manhattan       638.089888  170370.0
# Queens         1122.884058  232437.0
# Staten Island  1846.000000   55380.0

# %% [markdown]
# Q15: Create a pivot table of high schools from the Queens borough (*Borough*), containing the SAT section scores (*SAT Section*, *Score*) as columns and the school name (*School Name*) as index. Sort the table in descending order by math section scores.

# %%
#Q15
pivt = sat[(sat['Borough']=='Queens')]
pd.pivot_table(pivt,index='School Name',columns= 'SAT Section', values='Score',aggfunc={'Score':np.sum}).sort_values('Math',ascending=False)
# Out:
# SAT Section                                         Math  Reading  Writing
# School Name
# Queens High School for the Sciences at York Col...   701      621      625
# Townsend Harris High School                          680      640      661
# Baccalaureate School for Global Education            633      620      628
# Bard High School Early College Queens                631      598      610
# Scholars' Academy                                    588      560      568
# ...                                                  ...      ...      ...
# Middle College High School at LaGuardia Communi...   377      389      377
# Queens High School for Information, Research, a...   372      362      352
# August Martin High School                            366      372      364
# Rockaway Park High School for Environmental Sus...   357      381      376
# Pan American International High School               340      320      318
#
# [69 rows x 3 columns]

# %% [markdown]
# ## **Task2: Compute the distance between data points (30 points)**

# %% [markdown]
# This task uses a set of 10 data points, as given by the code block below. The numerical features of these data points are stored in a pandas `DataFrame` with the name `data`. The features are given the column names `x` and `y`. Their class labels are in a list `class_labels`. For example, the label of data point `[9,2]` is 1.

# %%
import pandas as pd

data = pd.DataFrame([[9,2], [2,3], [3,8], [4,4], [5,1], [6,7], [7,9], [8,4], [9,5], [4,7]], columns=["x","y"])
class_labels = [1, 1, 2, 1, 1, 2, 2, 2, 1, 2]

# %% [markdown]
# **(2.1)** - Write a piece of code to plot the 10-point dataset in a scatter plot using the `matplotlib` library  (https://matplotlib.org/3.5.1/api/_as_gen/matplotlib.pyplot.scatter.html). Points in class 1 should be represented in orange and those in class 2 should be in blue. Furthermore, show a new data point `[5,6]` in red.
#
# The code block below already provides the first several lines and the last line. Don't change these lines. Instead, fill in your code between them.
#
# The code on this page can give you some ideas about how to plot points in different colors https://www.codegrepper.com/code-examples/python/how+to+plot+two+different+class+in+different+colour+in+python.

# %%
# Code for 2.1
import matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))  
plt.xlim(0, 10)
plt.ylim(0, 10)
# DO NOT CHANGE ANYTHING ABOVE. FILL IN YOUR CODE BELOW.

# plot existing points
plt.scatter(data['x'], data['y'], c=class_labels, cmap=matplotlib.colors.ListedColormap(['orange','blue']))
#add new point [5,6] to scatter plot
plt.scatter(5, 6, c=3 ,cmap=matplotlib.colors.ListedColormap(['red']))

# DO NOT CHANGE ANYTHING BELOW. FILL IN YOUR CODE ABOVE.
plt.show()

# %% [markdown]
#  **(2.2)** - Write a piece of code to compute the Euclidean distance between the new data point `[5,6]` and all 10 points in the dataset. Save the distances in a list named `distances`. Note that you are required to implement the Euclidean distance function, and you are not allowed to use any existing implementation of it in any Python library.
#
# The code block below already provides the first line and the last several lines, in order to print out the values in the list `distances`. You are required to fill in your code inside the block. Your output should be essentially the same as the output under the code block below.

# %%
`
# Out:
# [5.657 4.243 2.828 2.236 5.    1.414 3.606 3.606 4.123 1.414]

# %% [markdown]
# *(2.3)** - Using the 10-point dataset, find the class label for the new data point `[5,6]` by applying the idea of 3-nearest neighbor classification. Save its class label in a variable `class_label`. Judging by the plot from (2.1), you can tell this point should be classified as blue, i.e., class 2.
#
# Note that you are required to implement 3-nearest neighbor classification for `[5,6]`, instead of calling any existing implementation.
#
# The code block below already provides the first line and the last line. The first line is to hard-code the content of `distances` so that you can successfully work on this task even if you couldn't manage to accomplish (2.2). The last line prints out the class label of the new data point. Your output should be the same.

# %%
# Code for 2.3
distances = [5.657, 4.243, 2.828, 2.236, 5, 1.414, 3.606, 3.606, 4.123, 1.414]
# DO NOT CHANGE ANYTHING ABOVE. FILL IN YOUR CODE BELOW.

print("Looking at the scatter plot we can easily conclide that the new point[5,6] belongs to class 2(blue color) \n")
k_indices = np.argsort(distances)[:3]  #fetch 3 nearest negihbour index
k_labels = [class_labels[x] for x in k_indices]
class_label = max(k_labels)

# DO NOT CHANGE ANYTHING BELOW. FILL IN YOUR CODE ABOVE.
print("class label : ", class_label)
# Out:
# Looking at the scatter plot we can easily conclide that the new point[5,6] belongs to class 2(blue color)
#
# class label :  2

# %% [markdown]
# ## **Task3: Compute the Gini Impurity,entropy and Information Gain (30 points)**

# %% [markdown]
#  **(3.1)** - Write a piece of code to compute Gini Impurity, Entropy
# and Information Gain for each split.
#
# Save the Gini Impurity in a list named `gini`,
# save the Information Gain in a list named `Informationgain`. Note that you are required to implement a function for each, and you are not allowed to use any existing implementation of it in any Python library.
# The data that is represented in the code block below are factors that affect whether you would go out to play golf or not.

# %%
from pandas.core.internals.construction import dataclasses_to_dicts
import pandas as pd

data = pd.DataFrame([['Rainy','Hot','High','False'],['Rainy','Hot','High','True'],['Overcast','Hot','High','False'],['Sunny','Mild','High','False'],['Sunny','Cool','Normal','False'],['Sunny','Cool','Normal','True'],['Overcast','Cool','Normal','True'],['Rainy','Mild','High','False'],['Rainy','Cool','Normal','False'],['Sunny','Mild','Normal','False'],['Rainy','Mild','Normal','True'],['Overcast','Mild','High','True'],['Overcast','Hot','Normal','False'],['Sunny','Mild','High','True']], columns=["Outlook","Temperature","Humidity","Windy"])
class_labels = ['No', 'No','Yes','Yes','Yes','No','Yes','No','Yes','Yes','Yes','Yes','Yes','No']
class_labels
col_list = list(data.columns)

data['class_labels']=class_labels
data['index1'] = data.index
print(data)
# Out:
#      Outlook Temperature Humidity  Windy class_labels  index1
# 0      Rainy         Hot     High  False           No       0
# 1      Rainy         Hot     High   True           No       1
# 2   Overcast         Hot     High  False          Yes       2
# 3      Sunny        Mild     High  False          Yes       3
# 4      Sunny        Cool   Normal  False          Yes       4
# 5      Sunny        Cool   Normal   True           No       5
# 6   Overcast        Cool   Normal   True          Yes       6
# 7      Rainy        Mild     High  False           No       7
# 8      Rainy        Cool   Normal  False          Yes       8
# 9      Sunny        Mild   Normal  False          Yes       9
# 10     Rainy        Mild   Normal   True          Yes      10
# 11  Overcast        Mild     High   True          Yes      11
# 12  Overcast         Hot   Normal  False          Yes      12
# 13     Sunny        Mild     High   True           No      13

# %%
 # Code for 3.1
import numpy as np 

def gini_impurity(df_column):
  gini_sub_branch = {}
  count_sub_feature = {}
  for sub_feature in df_column.unique():
    yes_count,no_count,total_count = 0,0,0
    for index in range(len(df_column)):
      if df_column[index]==sub_feature:
        total_count+=1
        if class_labels[index]=='Yes':
          yes_count+=1
        else:
          no_count+=1
      
    count_sub_feature[sub_feature] = total_count
    gini_value_of_sub_feature = 1 - (yes_count/(yes_count+no_count))**2 - (no_count/(yes_count+no_count))**2
    gini_sub_branch[sub_feature] = round(gini_value_of_sub_feature,2)

  total_gini_impurity = 0
  for sub_feature in gini_sub_branch:
    total_gini_impurity += (count_sub_feature[sub_feature]/len(df_column))*gini_sub_branch[sub_feature]
  return round(total_gini_impurity,2), gini_sub_branch

def entropy(y):
  y = pd.Series(y)
  a = y.value_counts()/y.shape[0]
  entropy = np.sum(-a*np.log2(a))
  return(entropy)

def information_gain(df_column):
  entropy_sub_branch = {}
  count_sub_feature = {}
  for sub_feature in df_column.unique():
    sub_class_labels = []
    total_count = 0
    for index in range(len(df_column)):
      if df_column[index]==sub_feature:
        total_count+=1
        sub_class_labels.append(class_labels[index])
      
    count_sub_feature[sub_feature] = total_count
    entropy_value_of_sub_feature = entropy(sub_class_labels)
    entropy_sub_branch[sub_feature] = round(entropy_value_of_sub_feature,2)
    
  total_info_impurity = entropy(class_labels)
  for sub_feature in entropy_sub_branch:
    total_info_impurity -= (count_sub_feature[sub_feature]/len(df_column))*entropy_sub_branch[sub_feature]
  return round(total_info_impurity,2),entropy_sub_branch

gini = {}
Informationgain = {}
for col in col_list:
  print("Entropy of ",col, entropy(data[col]))
  value,other_branches = gini_impurity(data[col])
  gini[col] = {value:other_branches}
  value2,other_branches2 = information_gain(data[col])
  Informationgain[col] = {value2:other_branches2}
  print("--------------------")
print("gini",gini)
print("Informationgain",Informationgain)
# Out:
# Entropy of  Outlook 1.5774062828523454
# --------------------
# Entropy of  Temperature 1.5566567074628228
# --------------------
# Entropy of  Humidity 1.0
# --------------------
# Entropy of  Windy 0.9852281360342515
# --------------------
# gini {'Outlook': {0.34: {'Rainy': 0.48, 'Overcast': 0.0, 'Sunny': 0.48}}, 'Temperature': {0.44: {'Hot': 0.5, 'Mild': 0.44, 'Cool': 0.38}}, 'Humidity': {0.36: {'High': 0.49, 'Normal': 0.24}}, 'Windy': {0.43: {'False': 0.38, 'True': 0.5}}}
# Informationgain {'Outlook': {0.25: {'Rainy': 0.97, 'Overcast': 0.0, 'Sunny': 0.97}}, 'Temperature': {0.03: {'Hot': 1.0, 'Mild': 0.92, 'Cool': 0.81}}, 'Humidity': {0.15: {'High': 0.99, 'Normal': 0.59}}, 'Windy': {0.05: {'False': 0.81, 'True': 1.0}}}

# %% [markdown]
# # **(3.2)** -  Perform the First Split using the  Information Gain
#
# 1.   List item
# 2.   List item

# %%
# Code for 3.2
# print(Informationgain)
def get_key(keyss):
  return list(keyss.keys())[0]
  
sorted_info_gain_dict = dict(sorted(Informationgain.items(), key = lambda x:get_key(x[1]),reverse=True))
for key,value in sorted_info_gain_dict.items():
  print("First Split Node :",key,sorted_info_gain_dict[key])
  break
# Out:
# First Split Node : Outlook {0.25: {'Rainy': 0.97, 'Overcast': 0.0, 'Sunny': 0.97}}

# %% [markdown]
# # **(3.3)** -Perform a further Split using the  Information Gain and complete the Decision Tree

# %%
# Code for 3.3
def information_gain2(feature):
  # print("feature",feature)
  dict_3 = {}
  for col in col_list:
    # print("col",col)
    entropy_sub_branch = {}
    count_sub_feature = {}
    total_count_2 = 0
    new_class_labels = []
    for sub_feature in data[col].unique():
      # print("-------------------------------------------")
      # print("sub_feature",sub_feature)
      sub_class_labels = []
      total_count = 0
      for i,j in data.iterrows():
        if j['Outlook']==feature and j[col]==sub_feature:
          total_count+=1
          total_count_2+=1
          sub_class_labels.append(class_labels[i])
          new_class_labels.append(class_labels[i])
      
      # print("sub_class_labels",sub_class_labels)
      count_sub_feature[sub_feature] = total_count
      entropy_value_of_sub_feature = entropy(sub_class_labels)
      # print("entropy_value_of_sub_feature",entropy_value_of_sub_feature)
      entropy_sub_branch[sub_feature] = round(entropy_value_of_sub_feature,2)

    total_info_impurity = entropy(new_class_labels)
    for sub_feature in entropy_sub_branch:
      total_info_impurity -= (count_sub_feature[sub_feature]/total_count_2)*entropy_sub_branch[sub_feature]

    dict_3[col] = {round(total_info_impurity,2):entropy_sub_branch}
    # print(dict_3)
  return dict_3

try:
  col_list.remove('Outlook')
except:
  pass

Informationgain = {}
for feature in ['Rainy','Overcast','Sunny']:
  
  Informationgain[feature] = information_gain2(feature)
  # print("--------------------")
print("Informationgain",Informationgain)
# Out:
# Informationgain {'Rainy': {'Temperature': {0.57: {'Hot': 0.0, 'Mild': 1.0, 'Cool': 0.0}}, 'Humidity': {0.97: {'High': 0.0, 'Normal': 0.0}}, 'Windy': {0.02: {'False': 0.92, 'True': 1.0}}}, 'Overcast': {'Temperature': {0.0: {'Hot': 0.0, 'Mild': 0.0, 'Cool': 0.0}}, 'Humidity': {0.0: {'High': 0.0, 'Normal': 0.0}}, 'Windy': {0.0: {'False': 0.0, 'True': 0.0}}}, 'Sunny': {'Temperature': {0.02: {'Hot': 0.0, 'Mild': 0.92, 'Cool': 1.0}}, 'Humidity': {0.02: {'High': 1.0, 'Normal': 0.92}}, 'Windy': {0.97: {'False': 0.0, 'True': 0.0}}}}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %% [markdown]
#  **(3.4)**
#
# Using the Information Gain , find the class label for the new data point ['Sunny','Hot','High','False']. Save its class label in a variable called class_label. Note that you are required to implement a Decision Tree, instead of calling any existing implementation.

# %%
# Code for 3.4
def _predict(a):
  for i in range(len(a)):
    if a[i] == 'Rainy':
      if a[i+2] == 'High':
        return 'Yes'
      else:
        return 'No'
    elif a[i] == 'Sunny':
      if a[i+3] == 'False':
        return 'Yes'
      else:
        return 'No'
    else:
      return 'Yes'

class_label = _predict(['Sunny','Hot','High','False'])
print(class_label)
# Out:
# Yes
